# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_excel("paimonmoe_wish_history.xlsx", sheet_name=0)
df1.head()
# Out:
#      Type                               Name                 Time  Stars  \
# 0  Weapon                          Raven Bow  2021-10-02 00:06:59      3
# 1  Weapon                        Emerald Orb  2021-10-03 11:54:23      3
# 2  Weapon                        Debate Club  2021-10-03 11:54:38      3
# 3  Weapon  Thrilling Tales of Dragon Slayers  2021-10-03 13:18:58      3
# 4  Weapon                          Slingshot  2021-10-03 17:30:23      3
#
#    Pity  #Roll  Group                 Banner Part
# 0     1      1      1  Drifting Luminescence  NaN
# 1     1      2      2  Drifting Luminescence  NaN
# 2     1      3      3  Drifting Luminescence  NaN
# 3     1      4      4  Drifting Luminescence  NaN
# 4     1      5      5  Drifting Luminescence  NaN

# %%
df2 = pd.read_excel("paimonmoe_wish_history.xlsx", sheet_name=1)
df2.head()
# Out:
#      Type                               Name                 Time  Stars  \
# 0  Weapon  Thrilling Tales of Dragon Slayers  2021-10-03 13:18:48      3
# 1  Weapon                     Skyrider Sword  2021-10-06 23:35:53      3
# 2  Weapon  Thrilling Tales of Dragon Slayers  2022-02-16 11:50:50      3
# 3  Weapon                          Raven Bow  2022-02-16 11:50:50      3
# 4  Weapon  Thrilling Tales of Dragon Slayers  2022-02-16 11:50:50      3
#
#    Pity  #Roll  Group              Banner  Part
# 0     1      1      1  Epitome Invocation   NaN
# 1     1      2      2  Epitome Invocation   NaN
# 2     1      1      1  Epitome Invocation   NaN
# 3     1      2      1  Epitome Invocation   NaN
# 4     1      3      1  Epitome Invocation   NaN

# %%
df3 = pd.read_excel("paimonmoe_wish_history.xlsx", sheet_name=2)
df3.head()
# Out:
#      Type                               Name                 Time  Stars  \
# 0  Weapon                          Slingshot  2021-10-02 00:07:15      3
# 1  Weapon                          Slingshot  2021-10-02 00:07:21      3
# 2  Weapon                        Emerald Orb  2021-10-02 00:07:26      3
# 3  Weapon                     Ferrous Shadow  2021-10-02 15:30:50      3
# 4  Weapon  Thrilling Tales of Dragon Slayers  2021-10-03 13:18:39      3
#
#    Pity  #Roll  Group                 Banner  Part
# 0     1      1      1  Wanderlust Invocation   NaN
# 1     1      2      2  Wanderlust Invocation   NaN
# 2     1      3      3  Wanderlust Invocation   NaN
# 3     1      4      4  Wanderlust Invocation   NaN
# 4     1      5      5  Wanderlust Invocation   NaN

# %%
df = pd.concat([df1, df2, df3])
df.drop('Part', axis=1, inplace=True)
df.to_csv('genshit.csv')
df.head()
# Out:
#      Type                               Name                 Time  Stars  \
# 0  Weapon                          Raven Bow  2021-10-02 00:06:59      3
# 1  Weapon                        Emerald Orb  2021-10-03 11:54:23      3
# 2  Weapon                        Debate Club  2021-10-03 11:54:38      3
# 3  Weapon  Thrilling Tales of Dragon Slayers  2021-10-03 13:18:58      3
# 4  Weapon                          Slingshot  2021-10-03 17:30:23      3
#
#    Pity  #Roll  Group                 Banner
# 0     1      1      1  Drifting Luminescence
# 1     1      2      2  Drifting Luminescence
# 2     1      3      3  Drifting Luminescence
# 3     1      4      4  Drifting Luminescence
# 4     1      5      5  Drifting Luminescence

# %%
type = np.array(df['Type'])
name = np.array(df['Name'])
stars = np.array([df['Stars']])
pity = np.array(df['Pity'])
roll = np.array(df['#Roll'])

# %%
name_stars = df[['Name', 'Stars']]
five_stars = []
for index, row in name_stars.iterrows():
    if row['Stars'] == 5:
        five_stars.append(row['Name'])

print(five_stars)
# Out:
# ['Tartaglia', 'Diluc', 'Raiden Shogun', 'Jean', 'Kamisato Ayato', 'Kamisato Ayato', 'Venti', 'Keqing', 'Kaedehara Kazuha', 'Zhongli', 'Jean', 'Yelan', 'Kamisato Ayaka', 'Dehya', 'Nahida', 'Eula', 'Tighnari', 'Neuvillette', 'Furina', 'Navia', 'Arlecchino', 'Jean', 'Primordial Jade Cutter', 'Lost Prayer to the Sacred Winds', 'Engulfing Lightning', 'Engulfing Lightning', 'Mistsplitter Reforged', "Amos' Bow", 'Vortex Vanquisher', "Jadefall's Splendor", 'The First Great Magic', "Crimson Moon's Semblance", 'Keqing', 'Skyward Pride', 'Mona', "Amos' Bow", 'Keqing', 'Diluc', 'Skyward Harp', 'Skyward Pride']

# %%
pity_char = df[['Pity', 'Name', 'Stars']]
pity_5stars_counts = []
for index, row in pity_char.iterrows():
    if row['Stars'] == 5:
        print(f"Pity: {row['Pity']}, Character: {row['Name']}.")
        pity_5stars_counts.append(row['Pity'])
print('-'*100)
average_pity = np.mean(pity_char[pity_char['Stars'] == 5]['Pity'])
print(f'Average Pity: {int(average_pity)}')
# Out:
# Pity: 80, Character: Tartaglia.
# Pity: 41, Character: Diluc.
# Pity: 74, Character: Raiden Shogun.
# Pity: 66, Character: Jean.
# Pity: 8, Character: Kamisato Ayato.
# Pity: 9, Character: Kamisato Ayato.
# Pity: 78, Character: Venti.
# Pity: 61, Character: Keqing.
# Pity: 79, Character: Kaedehara Kazuha.
# Pity: 60, Character: Zhongli.
# Pity: 83, Character: Jean.
# Pity: 78, Character: Yelan.
# Pity: 41, Character: Kamisato Ayaka.
# Pity: 82, Character: Dehya.
# Pity: 76, Character: Nahida.
# Pity: 81, Character: Eula.
# Pity: 77, Character: Tighnari.
# Pity: 6, Character: Neuvillette.
# Pity: 77, Character: Furina.
# Pity: 75, Character: Navia.
# Pity: 75, Character: Arlecchino.
# Pity: 80, Character: Jean.
# Pity: 68, Character: Primordial Jade Cutter.
# Pity: 2, Character: Lost Prayer to the Sacred Winds.
# Pity: 66, Character: Engulfing Lightning.
# Pity: 36, Character: Engulfing Lightning.
# Pity: 31, Character: Mistsplitter Reforged.
# Pity: 64, Character: Amos' Bow.
# ...

# %%
pity_char = df[['Pity', 'Name', 'Stars']]
pity_char_5stars = pity_char[pity_char['Stars'] == 5]

five_stars_counts = pity_char_5stars['Name'].value_counts()
occurrences = {}
for index, row in pity_char_5stars.iterrows():
    char_name = row['Name']
    if char_name in occurrences:
        occurrences[char_name] += 1
    else:
        occurrences[char_name] = 1

for char_name, count in occurrences.items():
    print(f"Character: {char_name}, Constellations: C{count - 1}")
# Out:
# Character: Tartaglia, Constellations: C0
# Character: Diluc, Constellations: C1
# Character: Raiden Shogun, Constellations: C0
# Character: Jean, Constellations: C2
# Character: Kamisato Ayato, Constellations: C1
# Character: Venti, Constellations: C0
# Character: Keqing, Constellations: C2
# Character: Kaedehara Kazuha, Constellations: C0
# Character: Zhongli, Constellations: C0
# Character: Yelan, Constellations: C0
# Character: Kamisato Ayaka, Constellations: C0
# Character: Dehya, Constellations: C0
# Character: Nahida, Constellations: C0
# Character: Eula, Constellations: C0
# Character: Tighnari, Constellations: C0
# Character: Neuvillette, Constellations: C0
# Character: Furina, Constellations: C0
# Character: Navia, Constellations: C0
# Character: Arlecchino, Constellations: C0
# Character: Primordial Jade Cutter, Constellations: C0
# Character: Lost Prayer to the Sacred Winds, Constellations: C0
# Character: Engulfing Lightning, Constellations: C1
# ...

# %%
num_5_stars = len(pity_5stars_counts)
five_stars_shows = []
for i in range(num_5_stars):
    five_stars_shows.append(5)

fig, ax = plt.subplots()
ax.scatter(five_stars_shows, pity_5stars_counts)
ax.xaxis.set_visible(False)
plt.title('5 Stars Character Pity Plot')
plt.ylabel('Pity')
plt.xlabel('Characters')
plt.show()

# %%
pity_char = df[['Pity', 'Name', 'Stars', 'Type']]
pity_4stars_counts = []
for index, row in pity_char.iterrows():
    if row['Stars'] == 4:
        print(f"Pity: {row['Pity']}, Name: {row['Name']}.")
        pity_4stars_counts.append(row['Pity'])
print()
average_pity = np.mean(pity_char[pity_char['Stars'] == 4]['Pity'])
print(f'Average Pity: {int(average_pity)}')
# Out:
# Pity: 10, Name: Rosaria.
# Pity: 9, Name: Rosaria.
# Pity: 10, Name: Rosaria.
# Pity: 10, Name: Favonius Greatsword.
# Pity: 9, Name: Yanfei.
# Pity: 9, Name: The Stringless.
# Pity: 9, Name: Yanfei.
# Pity: 10, Name: Ningguang.
# Pity: 10, Name: Favonius Sword.
# Pity: 6, Name: Diona.
# Pity: 10, Name: The Bell.
# Pity: 4, Name: Thoma.
# Pity: 5, Name: Favonius Lance.
# Pity: 9, Name: Bennett.
# Pity: 6, Name: Favonius Greatsword.
# Pity: 6, Name: Rosaria.
# Pity: 10, Name: Chongyun.
# Pity: 9, Name: Bennett.
# Pity: 6, Name: The Stringless.
# Pity: 9, Name: Rosaria.
# Pity: 5, Name: Rust.
# Pity: 10, Name: Rosaria.
# Pity: 7, Name: Sayu.
# Pity: 5, Name: Xinyan.
# Pity: 10, Name: Bennett.
# Pity: 10, Name: Favonius Sword.
# Pity: 9, Name: Bennett.
# Pity: 10, Name: Favonius Sword.
# Pity: 9, Name: Xinyan.
# Pity: 9, Name: The Bell.
# Pity: 9, Name: Xinyan.
# Pity: 9, Name: The Stringless.
# Pity: 2, Name: Xiangling.
# Pity: 10, Name: Favonius Codex.
# Pity: 7, Name: Yun Jin.
# ...

# %%
pity_char_4stars = df[(df['Stars'] == 4)]
four_stars_counts = pity_char_4stars['Name'].value_counts()
occurrences = {}
for index, row in pity_char_4stars.iterrows():
    char_name = row['Name']
    if char_name in occurrences:
        occurrences[char_name] += 1
    else:
        occurrences[char_name] = 1

for char_name, count in occurrences.items():
    if count >=6:
        count = 7
    print(f"Name: {char_name}, Constellations: C{count - 1}")
# Out:
# Name: Rosaria, Constellations: C6
# Name: Favonius Greatsword, Constellations: C6
# Name: Yanfei, Constellations: C3
# Name: The Stringless, Constellations: C6
# Name: Ningguang, Constellations: C6
# Name: Favonius Sword, Constellations: C6
# Name: Diona, Constellations: C6
# Name: The Bell, Constellations: C6
# Name: Thoma, Constellations: C6
# Name: Favonius Lance, Constellations: C4
# Name: Bennett, Constellations: C6
# Name: Chongyun, Constellations: C2
# Name: Rust, Constellations: C6
# Name: Sayu, Constellations: C2
# Name: Xinyan, Constellations: C6
# Name: Xiangling, Constellations: C6
# Name: Favonius Codex, Constellations: C6
# Name: Yun Jin, Constellations: C2
# Name: Eye of Perception, Constellations: C6
# Name: Sucrose, Constellations: C6
# Name: Sacrificial Fragments, Constellations: C3
# Name: Sacrificial Sword, Constellations: C6
# Name: Favonius Warbow, Constellations: C1
# Name: Gorou, Constellations: C1
# Name: Kuki Shinobu, Constellations: C6
# ...

# %%
num_4_stars = len(pity_4stars_counts)
four_stars_shows = []
for i in range(num_4_stars):
    four_stars_shows.append(4)

fig, ax = plt.subplots()
ax.scatter(four_stars_shows, pity_4stars_counts)
ax.xaxis.set_visible(False)
plt.title('4 Stars Character Pity Plot')
plt.ylabel('Pity')
plt.xlabel('Characters')
plt.show()

# %%
dd = df.drop(['Type', 'Name', 'Time', 'Banner'], axis=1)
ddc = dd.corr()
sns.heatmap(ddc, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
from ydata_profiling import ProfileReport
import pandas as pd
df = pd.read_csv(r'D:\Coding\Python\bullshit project\genshit.csv')
profile = ProfileReport(df, title="Profiling Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.10.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-09-10 03:48:45.855902&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
